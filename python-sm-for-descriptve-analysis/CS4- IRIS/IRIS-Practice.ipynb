# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  sepal length  sepal width  petal length  petal width
# 0           0          5.10         3.50          1.40         0.20
# 1           1          4.90         3.00          1.40         0.20
# 2           2          4.70         3.20          1.30         0.20
# 3           3          4.60         3.10          1.50         0.20
# 4           4          5.00         3.60          1.40         0.20

# %%
df.shape
# Out:
# (150, 5)

# %%
df['sepal length'].mean()
# Out:
# 5.843333333333335

# %%
df['sepal length'].std()
# Out:
# 0.8280661279778629

# %%
sns.scatterplot(data=df, x='sepal length', y='sepal width');

# %%
sns.boxplot(data=df, x='petal width');

# %%
sns.boxplot(data=df, x='petal length');

# %%
sns.boxplot(data=df, x='sepal width');

# %%
sns.boxplot(data=df, x='sepal length');

# %%
15000/212000
# Out:
# 0.07075471698113207

# %%
1500/5020
# Out:
# 0.29880478087649404

# %%
4000/30000
# Out:
# 0.13333333333333333
